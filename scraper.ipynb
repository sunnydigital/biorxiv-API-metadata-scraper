# %% [markdown]
# ## Initial Test
#
# ---
#
# Initial test to try and attempt to view what a sample `JSON` output would look like

# %%
import os
import requests
import json
import time
import calendar
import numpy as np

from datetime import date, timedelta
from urllib.parse import urljoin
from pathlib import Path

# %% [markdown]
# ### Settings & Explanations
#
# ---
#
# In the below, we play with the data ranges, between `2018-08-21` and another date
#
# However, it turns out the same date can be used for multiple entries, therefore simplifying the extraction of dates for a single date

# %%
day = 16
month = 3
year = 2014

lezo_fx = lambda x: "0" + str(x) if len(str(x)) == 1 else str(x) ## LEading ZEro lambda function to get properly formatted dates
url = f'https://api.biorxiv.org/details/biorxiv/{year}-{lezo_fx(month)}-{lezo_fx(day)}/{year}-{lezo_fx(month)}-{lezo_fx(day)}/0'
response = requests.get(url)

response.raise_for_status()

data = response.json()

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "messages": [
#     {
#       "status": "ok",
#       "interval": "2014-03-16:2014-03-16",
#       "cursor": 0,
#       "count": 1,
#       "count_new_papers": 1,
#       "total": 1
#     }
#   ],
#   "collection": [
#     {
#       "doi": "10.1101/003319",
#       "title": "Genetic influences on translation in yeast",
#       "authors": "Frank W. Albert;Dale Muzzey;Jonathan S. Weissman;Leonid Kruglyak;",
#       "author_corresponding": "Frank W. Albert",
#       "author_corresponding_institution": "University of California, Los Angeles",
#       "date": "2014-03-16",
#       "version": "1",
#       "type": "New Results",
#       "license": "cc_by_nc_nd",
#       "category": "Genetics ",
#       "jatsxml": "https://www.biorxiv.org/content/early/2014/03/16/003319.source.xml",
#       "abstract": "Heritable differences in gene expression between individuals are an important source of phenotypic variation. The question of how closely the effects of genetic variation on protein levels mirror those on mRNA levels remains open. Here, we addressed this question by using ribosome profiling to examine how genetic differences between two strains of the yeast S. cerevisiae affect translation. Strain differences in translation were observed for hundreds of genes. Allele specific measurements in the diploid hybrid between the two strains revealed roughly half as many cis-acting effects on translation as were observed for mRNA levels. In both the parents and the hybrid, most effects on translation were of small magnitude, such that the direction of an mRNA difference was typically reflected in a concordant footprint difference. The relative importance of cis and trans acting variation on footprint levels was similar to that for mRNA levels. There was a tendency for translation to cause larger footprint differences than expected given the respective mRNA differences. This is in contrast to translational differences between yeast species that have been reported to more often oppose than reinforce mRNA differences. Finally, we catalogued instances of premature translation termination in the two yeast strains and also found several instances where erroneous reference gene annotations lead to apparent nonsense mutations that in fact reside outside of the translated gene body. Overall, genetic influences on translation subtly modulate gene expression differences, and translation does not create strong discrepancies between genetic influences on mRNA and protein levels.\\n\\nAuthor summaryIndividuals in a species differ from each other in many ways. For many traits, a fraction of this variation is genetic - it is caused by DNA sequence variants in the genome of each individual. Some of these variants influence traits by altering how much certain genes are expressed, i.e. how many mRNA and protein molecules are made in different individuals. Surprisingly, earlier work has found that the effects of genetic variants on mRNA and protein levels for the same genes appear to be very different. Many variants appeared to influence only mRNA (but not protein) levels, and vice versa. In this paper, we studied this question by using a technique called \\\"ribosome profiling\\\" to measure translation (the cellular process of reading mRNA molecules and synthesizing protein molecules) in two yeast strains. We found that the genetic differences between these two strains influence translation for hundreds of genes. Because most of these effects were small in magnitude, they explain at most a small fraction of the discrepancies between the effects of genetic variants on mRNA and protein levels.",
#       "published": "10.1371/journal.pgen.1004692",
#       "server": "biorxiv"
#     }
#   ]
# }

# %% [markdown]
# ## API Access w/ Certain Considerations
#
# ---
#
# In this portion, the we will collect a few JSONs:
#
# - `full_dict_by_date`: A JSON object with dates as keys representing the output of bioRxiv metadata for each article from 01-01-2013 onwards
#
#     - This will be futher deposited into folders for monthly and then yearly collection henceforth
#
# - `return_dict` A JSON object of JSON objects
#
#     - The first JSON object will have keys of DOI
#     - And values of the `date`, `license`, and `jatsxml`
#         - These will represent an easy-to-access format for the data
#
#     - The second JSON object will have keys of the license types (i.e. `CC-BY`) and values of the counts of each license type
#
#         - This is specifically for the creation of a pie chart for breakdown by license type
#
# - `full_dict`: A JSON object representing the full output of each request
#
#     - The name of the object will be the date associated
#
#     - This object will be deposited into a folder system with subfolder system in the format:
#
#         `full_dict`
#
#             L year1
#
#                 L month1
#
#                     L day1
#                     L day2
#
#                 L month2
#
#                     L day1
#                     L day2
#                     L day3
#
#             L year2
#
#                 L month1
#
#                     L day1
#                     L day2
#                     L day3
#
#                 L month2
#
#                     L day1
#
# Each of the above mentioned dictionaries will have methods of saving and retrieving in the main loop

# %%
def update_return_dict(articles, cur_date):
    '''
    This function processes all of the articles associated with a specific date, it checks:
        1) Whether the current DOI has ALREADY been processed, if so updates the saved JATSXML link in associated JSON
        2) Whether the key for the license associated with the current article exists, if so, a new key is then created and added to the JSON value for that key in particular
            @param article: The article JSON object to be processed
            @return: None
    '''
    cur_date = str(cur_date)
    articles = articles['collection']
    for article in articles:
        ## Tracks the number of license type count from the return_dict "license" object
        return_dict['license'][article['license']] = return_dict['license'].get(article['license'], 0) + 1

        ## Adds/UPDATES the most recent DOI submission from return_dict
        return_dict['content'][article['doi']] = {
            'date': article['date'],
            'license': article['license'],
            'jatsxml': article['jatsxml']
        }

# %%
def update_full_dict_by_date(articles, cur_date):
    '''
    This function adds to a dict object where the keys are the dates in string format and the values are a list of DOIs for that date
        @param articles: All articles in current date to extract information from
        @param cur_date: The current date to process in YYYY-mm-dd format
        @return: None
    '''
    cur_date = str(cur_date)
    articles = articles['collection']
    
    full_dict_by_date[cur_date] = [{'doi': item['doi'], 'license': item['license']} for item in articles]

# %%
def get_dated_subfolders(date):
    '''
    Function to create subfolders for each of the day, month, year in the current date, specifically to store metadata from "full_dict_by_date"
        @param date: The current date in YYYY-mm-dd format
        @return: The full output path for the folder representing the current date
    '''
    month = date.month
    year = date.year

    dict_main_folder = Path('./full-dict')

    dict_year_folder = dict_main_folder.joinpath(str(year))
    dict_year_folder.mkdir(exist_ok=True)

    dict_month_folder = dict_year_folder.joinpath(str(month))
    dict_month_folder.mkdir(exist_ok=True)

    return dict_month_folder

# %%
def split_dates(dates, num_splits):
    '''
    Function that takes in a list of dates (or anything, really) and splits those dates into num_splits number of splits
        @param dates: A list of dates (or anything really)
        @param num_splits: The number of sub-lists to split the original list into
    '''
    first_last_dates_fx = lambda lis: [[li[0], li[-1]] for li in lis] ## Essentially extracts the first and last elements of the split list of dates
    return list(first_last_dates_fx(np.array_split(dates, num_splits))) ## Returns the first and last dates of each split

# %%
def get_split_folder(split_num):
    '''
    Function that creates a folder for the specific split applicable to the current operation
        @param split_num: The split number to obtain the associated folder for
        @return: The path to the folder for the split number
    '''
    split_main_folder = Path('./output_dicts/')
    split_main_folder.mkdir(exist_ok=True)

    split_folder = split_main_folder.joinpath(str(split_num))
    split_folder.mkdir(exist_ok=True)

    return split_folder ## Not needed but just in case

# %%
def process_bioRxiv(start_date=lambda _: date(2013, 1, 1),
                    end_date=lambda _: date.today(),
                    load_dicts=False,
                    delay=5,
                    **kwargs):
    '''
    Function to process the data (loading in if necessary) for a period of time defined by:
        @param start: Beginning date in the format YYYY-mm-dd
        @param end: End date in the format YYY-mm-dd
        @param save_every: Saves (overrites) the last dict every n number of iterations through the data
        @param load_dicts: Loads in the dictionary (JSON) objects associated with "full_dict_by_date" and "return_dict"
    '''
    global full_dict_by_date
    full_dict_by_date = {}

    global return_dict
    return_dict = {
        'license': {},
        'content': {}
    }

    get_split_folder(SELECTED_NUMBER) ## Creates the folder for the current split number

    if load_dicts:
        with open(f'{SELECTED_NUMBER if SELECTED_NUMBER else "."}/full_dict_by_date.json', 'r') as f:
            full_dict_by_date = json.load(f)
        with open(f'{SELECTED_NUMBER if SELECTED_NUMBER else "."}/return_dict.json', 'r') as f:
            return_dict = json.load(f)

        start_date = date(full_dict_by_date.keys().sort()[-1]) + timedelta(days=1) ## Gets the last available date and adds 1 IF not the first date, otherwise starts at Jan 1, 2013

    dates = [start_date + timedelta(days=x) for x in range((end_date  - start_date).days + 1)] ## Gets a list of available dates

    for cur_date in dates:

        flag = True ## Flag of whether or not to continue the loop to get more pages
        num_skip = 0 ## Flag to skip as per API instructions
        while flag:
            cur_date_dir = get_dated_subfolders(cur_date)

            url = f'https://api.biorxiv.org/details/biorxiv/{str(cur_date)}/{str(cur_date)}/{num_skip}'

            response = requests.get(url) ## Processes request and waits for response / articles in JSON format
            response.raise_for_status()
            articles = response.json()

            if articles['messages'][0]['status'] != 'ok': ## Continues onto the next date if posts for the current date are unavailable
                flag = False
                continue

            update_full_dict_by_date(articles=articles, cur_date=cur_date)
            update_return_dict(articles=articles, cur_date=cur_date)

            print(f'Saving "full_dict_by_date.json" to folder "{SELECTED_NUMBER}"...')
            with open(f'./output_dicts/{SELECTED_NUMBER}/full_dict_by_date.json', 'w') as f:
                json.dump(full_dict_by_date, f, indent=2)
            
            print(f'Saving "return_dict.json" to folder "{SELECTED_NUMBER}"...')
            with open(f'./output_dicts/{SELECTED_NUMBER}/return_dict.json', 'w') as f:
                json.dump(return_dict, f, indent=2)

            print(f'Saving "full_dict_by_date.json" to folder "{str(cur_date_dir)}"...') ## Saves the updated JSONs
            with open(f'{str(cur_date_dir)}/{cur_date}.json', 'w') as f: ## Saves the whole output as today's date
                json.dump(articles['collection'], f, indent=2)

            print('='*50)
            print('Processed date:', cur_date, 'with', len(articles['collection']), 'articles')
            print(f'Sleeping for {delay} second(s)... Zzz...')
            print('='*50)
            time.sleep(delay) ## Uses the default 5 seconds if need be

            num_skip += 100

# %% [markdown]
# # Directions for Asynchronous Users
#
# ---
#
# From the number you chose in the Discord server, please enter the number in the following cell under `SELECTED NUMBER`.
#
# DO NOT change the `DO_NOT_CHANGE_FLAG` flag. This represents the number of total splits to use.
#
# Afterwards, simply sync the current folder containing all the metadata with GitHub.

# %%
global DO_NOT_CHANGE_FLAG
DO_NOT_CHANGE_FLAG = 100 ## Do not change this number, it is the number of splits to create and is set standard to 100

# %%
LEFT_OFF = 96 ## The split number to start from, if 0, then starts from the beginning

# %% [markdown]
# ## Note
#
# ---
#
# The below dates are relevant to a start date of 9/04/2023 for initial scraping of the data. For all concurrent updates, refer to the initial date of the first scrape.

# %%
USE_TODAY = True ## Whether or not to use today's date as the end date or to use the end date specified below

# %%
for num in range(LEFT_OFF, DO_NOT_CHANGE_FLAG):
    global SELECTED_NUMBER
    SELECTED_NUMBER = num ## Enter selected number here, which represents the selected number

    dates = [date(2013, 1, 1) + timedelta(days=x) for x in range(((date.today() if USE_TODAY else date(2023, 9, 4)) - date(2013, 1, 1)).days + 1)] ## Gets a list of available dates
    split_dates_list = split_dates(dates, DO_NOT_CHANGE_FLAG) ## Splits the dates into the selected number of splits

    start_date = split_dates_list[SELECTED_NUMBER][0] ## Gets the start date from the selected number
    end_date = split_dates_list[SELECTED_NUMBER][1] ## Gets the end date from the selected number

    process_bioRxiv(start_date=start_date, end_date=end_date, save_every_n_days=100, load_dicts=False, delay=1)
# Out:
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-03 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-03 with 95 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-04 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-04 with 44 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-05 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-05 with 36 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-06 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-06 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-06 with 54 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-07 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-07 with 26 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-08 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-08 with 2 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-09 with 52 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-10 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-10 with 14 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-11 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-11 with 7 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-12 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-12 with 95 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-13 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-13 with 59 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-14 with 31 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-15 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-15 with 32 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-16 with 70 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-17 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-17 with 58 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-18 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-18 with 85 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-19 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-19 with 39 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-20 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-20 with 67 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-21 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-21 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-21 with 42 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-22 with 50 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-23 with 41 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-24 with 50 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-25 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-25 with 56 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-26 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-26 with 25 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-27 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-27 with 17 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-28 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-28 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-28 with 62 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-29 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-29 with 37 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\4...
# ==================================================
# Processed date: 2023-04-30 with 79 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-01 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-01 with 19 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-02 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-02 with 93 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-03 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-03 with 53 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-04 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-04 with 48 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-05 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-05 with 51 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-06 with 38 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-07 with 75 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-08 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-08 with 59 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-09 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-09 with 81 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-10 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-10 with 88 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-11 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 96...
# Saving "return_dict.json" to folder 96...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-11 with 48 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-12 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-12 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-12 with 4 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-13 with 79 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-14 with 76 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-15 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-15 with 40 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-16 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-16 with 10 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-17 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-17 with 54 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-18 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-18 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-18 with 3 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-19 with 86 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-20 with 92 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-21 with 63 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-22 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-22 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-22 with 20 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-23 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-23 with 71 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-24 with 18 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-25 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-25 with 74 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-26 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-26 with 61 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-27 with 37 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-28 with 68 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-29 with 84 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-30 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-30 with 83 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-31 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\5...
# ==================================================
# Processed date: 2023-05-31 with 26 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-01 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-01 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-01 with 28 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-02 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-02 with 10 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-03 with 88 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-04 with 72 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-05 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-05 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-05 with 30 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-06 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-06 with 57 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-07 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-07 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-07 with 70 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-08 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-08 with 31 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-09 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-09 with 57 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-10 with 59 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-11 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-11 with 28 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-12 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-12 with 53 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-13 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-13 with 68 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-14 with 9 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-15 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-15 with 97 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 97...
# Saving "return_dict.json" to folder 97...
# Saving "full_dict_by_date.json" to folder full-dict\2023\6...
# ==================================================
# Processed date: 2023-06-16 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-12 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-12 with 16 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-13 with 73 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-14 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-14 with 48 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-15 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-15 with 43 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-16 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-16 with 77 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-17 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-17 with 70 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-18 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-18 with 24 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-19 with 90 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-20 with 77 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-21 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-21 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-21 with 5 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-22 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-22 with 79 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-23 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-23 with 35 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-24 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-24 with 13 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-25 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-25 with 3 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-26 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-26 with 70 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-27 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-27 with 33 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-28 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-28 with 61 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-29 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-29 with 84 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-30 with 91 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-31 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\8...
# ==================================================
# Processed date: 2023-08-31 with 81 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-01 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-01 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-01 with 25 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-02 with 76 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-03 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-03 with 5 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-04 with 100 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-04 with 6 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================
# Saving "full_dict_by_date.json" to folder 99...
# Saving "return_dict.json" to folder 99...
# Saving "full_dict_by_date.json" to folder full-dict\2023\9...
# ==================================================
# Processed date: 2023-09-05 with 47 articles
# Sleeping for 1 second(s)... Zzz...
# ==================================================

# %% [markdown]
# # Combine
#
# ---
#
# The below section deals with combining all of the obtained data into one single JSON object

# %%
def combine_output_dicts(path='./output_dicts', save_path='./global_dicts', num=0):
    '''
    Function to combine all of the output dicts into one JSON file by creating a placeholder, temporary dict and adding all of the values from the other dicts to it
        This operates on the previously defined global dictionalry objects "full_return_dict" and "full_return_dict_by_date"
        @param path: The path to the folder containing all of the output dicts
        @return: None
    '''
    try:
        with open(f'{path}/{num}/return_dict.json', 'r') as f:
            cur_return_dict = json.load(f)

        with open(f'{path}/{num}/full_dict_by_date.json', 'r') as f:
            cur_return_dict_by_date = json.load(f)

        print(f'Combining and saving "return_dict" license values for folder {num}...')
        global_return_dict['license'] = {key: global_return_dict['license'].get(key, 0) + value for key, value in cur_return_dict['license'].items()} ## Adds the license counts to the global dict for each license count
        with open(f'{save_path}/return_dict.json', 'w') as f:
            json.dump(global_return_dict, f, indent=2)

        print(f'Combining and saving "full_dict_by_date" content items for folder {num}...')
        global_return_dict['content'].update(cur_return_dict['content']) ## Adds the content to the global dict
        with open(f'{save_path}/full_dict_by_date.json', 'w') as f:
            json.dump(global_return_dict['content'], f, indent=2)
        

    except FileNotFoundError:
        print(f'No files in folder {num}, continuing to the next folder...')

# %%
global global_return_dict
global_return_dict = {
    'license': {},
    'content': {}
}

global global_return_dict_by_date
full_return_dict_by_date = {}

# %%
def get_global_folder():
    '''
    Function to create the global folder for the combined JSONs
        @return: The path to the global folder
    '''
    global_folder = Path('./global_dicts/')
    global_folder.mkdir(exist_ok=True)

    return global_folder

# %%
for num in range(DO_NOT_CHANGE_FLAG):
    combine_output_dicts(path='./output_dicts/',save_path=lambda _: get_global_folder(), num=num)
# Out:
# No files in folder 0, continuing to the next folder...
# No files in folder 1, continuing to the next folder...
# No files in folder 2, continuing to the next folder...
# No files in folder 3, continuing to the next folder...
# No files in folder 4, continuing to the next folder...
# No files in folder 5, continuing to the next folder...
# No files in folder 6, continuing to the next folder...
# Combining and saving "return_dict" license values for folder 7...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13328\2081415509.py in <module>
#       1 for num in range(DO_NOT_CHANGE_FLAG):
# ----> 2     combine_output_dicts(path='./output_dicts/',save_path=lambda _: get_global_folder(), num=num)
#
# ~\AppData\Local\Temp\ipykernel_13328\204299116.py in combine_output_dicts(path, save_path, num)
#      15         print(f'Combining and saving "return_dict" license values for folder {num}...')
#      16         global_return_dict['license'] = {key: global_return_dict['license'].get(key, 0) + value for key, value in cur_return_dict['license'].items()} ## Adds the license counts to the global dict for each license count
# ---> 17         with open(f'{save_path}/return_dict.json', 'w') as f:
#      18             json.dump(global_return_dict, f, indent=2)
#      19
#
# OSError: [Errno 22] Invalid argument: '<function <lambda> at 0x000002903D011D30>/return_dict.json'
