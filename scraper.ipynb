# %% [markdown]
# ## Initial Test
#
# ---
#
# Initial test to try and attempt to view what a sample `JSON` output would look like

# %%
import os
import requests
import json
import time
import calendar
import numpy as np

from datetime import date, timedelta
from urllib.parse import urljoin
from pathlib import Path

# %% [markdown]
# ### Settings & Explanations
#
# ---
#
# In the below, we play with the data ranges, between `2018-08-21` and another date
#
# However, it turns out the same date can be used for multiple entries, therefore simplifying the extraction of dates for a single date

# %%
day = 16
month = 3
year = 2014

lezo_fx = lambda x: "0" + str(x) if len(str(x)) == 1 else str(x) ## LEading ZEro lambda function to get properly formatted dates
url = f'https://api.biorxiv.org/details/biorxiv/{year}-{lezo_fx(month)}-{lezo_fx(day)}/{year}-{lezo_fx(month)}-{lezo_fx(day)}/0'
response = requests.get(url)

response.raise_for_status()

data = response.json()

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "messages": [
#     {
#       "status": "ok",
#       "interval": "2014-03-16:2014-03-16",
#       "cursor": 0,
#       "count": 1,
#       "count_new_papers": 1,
#       "total": 1
#     }
#   ],
#   "collection": [
#     {
#       "doi": "10.1101/003319",
#       "title": "Genetic influences on translation in yeast",
#       "authors": "Frank W. Albert;Dale Muzzey;Jonathan S. Weissman;Leonid Kruglyak;",
#       "author_corresponding": "Frank W. Albert",
#       "author_corresponding_institution": "University of California, Los Angeles",
#       "date": "2014-03-16",
#       "version": "1",
#       "type": "New Results",
#       "license": "cc_by_nc_nd",
#       "category": "Genetics ",
#       "jatsxml": "https://www.biorxiv.org/content/early/2014/03/16/003319.source.xml",
#       "abstract": "Heritable differences in gene expression between individuals are an important source of phenotypic variation. The question of how closely the effects of genetic variation on protein levels mirror those on mRNA levels remains open. Here, we addressed this question by using ribosome profiling to examine how genetic differences between two strains of the yeast S. cerevisiae affect translation. Strain differences in translation were observed for hundreds of genes. Allele specific measurements in the diploid hybrid between the two strains revealed roughly half as many cis-acting effects on translation as were observed for mRNA levels. In both the parents and the hybrid, most effects on translation were of small magnitude, such that the direction of an mRNA difference was typically reflected in a concordant footprint difference. The relative importance of cis and trans acting variation on footprint levels was similar to that for mRNA levels. There was a tendency for translation to cause larger footprint differences than expected given the respective mRNA differences. This is in contrast to translational differences between yeast species that have been reported to more often oppose than reinforce mRNA differences. Finally, we catalogued instances of premature translation termination in the two yeast strains and also found several instances where erroneous reference gene annotations lead to apparent nonsense mutations that in fact reside outside of the translated gene body. Overall, genetic influences on translation subtly modulate gene expression differences, and translation does not create strong discrepancies between genetic influences on mRNA and protein levels.\\n\\nAuthor summaryIndividuals in a species differ from each other in many ways. For many traits, a fraction of this variation is genetic - it is caused by DNA sequence variants in the genome of each individual. Some of these variants influence traits by altering how much certain genes are expressed, i.e. how many mRNA and protein molecules are made in different individuals. Surprisingly, earlier work has found that the effects of genetic variants on mRNA and protein levels for the same genes appear to be very different. Many variants appeared to influence only mRNA (but not protein) levels, and vice versa. In this paper, we studied this question by using a technique called \\\"ribosome profiling\\\" to measure translation (the cellular process of reading mRNA molecules and synthesizing protein molecules) in two yeast strains. We found that the genetic differences between these two strains influence translation for hundreds of genes. Because most of these effects were small in magnitude, they explain at most a small fraction of the discrepancies between the effects of genetic variants on mRNA and protein levels.",
#       "published": "10.1371/journal.pgen.1004692",
#       "server": "biorxiv"
#     }
#   ]
# }

# %% [markdown]
# ## API Access w/ Certain Considerations
#
# ---
#
# In this portion, the we will collect a few JSONs:
#
# - `full_dict_by_date`: A JSON object with dates as keys representing the output of bioRxiv metadata for each article from 01-01-2013 onwards
#
#     - This will be futher deposited into folders for monthly and then yearly collection henceforth
#
# - `return_dict` A JSON object of JSON objects
#
#     - The first JSON object will have keys of DOI
#     - And values of the `date`, `license`, and `jatsxml`
#         - These will represent an easy-to-access format for the data
#
#     - The second JSON object will have keys of the license types (i.e. `CC-BY`) and values of the counts of each license type
#
#         - This is specifically for the creation of a pie chart for breakdown by license type
#
# - `full_dict`: A JSON object representing the full output of each request
#
#     - The name of the object will be the date associated
#
#     - This object will be deposited into a folder system with subfolder system in the format:
#
#         `full_dict`
#             L year1
#                 L month1
#                     L day1
#                     L day2
#                 L month2
#                     L day1
#                     L day2
#                     L day3
#             L year2
#                 L month1
#                     L day1
#                     L day2
#                     L day3
#                 L month2
#                     L day1
#
# Each of the above mentioned dictionaries will have methods of saving and retrieving in the main loop

# %%
def update_return_dict(articles, cur_date):
    '''
    This function processes all of the articles associated with a specific date, it checks:
        1) Whether the current DOI has ALREADY been processed, if so updates the saved JATSXML link in associated JSON
        2) Whether the key for the license associated with the current article exists, if so, a new key is then created and added to the JSON value for that key in particular
            @param article: The article JSON object to be processed
            @return: None
    '''
    cur_date = str(cur_date)
    articles = articles['collection']
    for article in articles:
        ## Tracks the number of license type count from the return_dict "license" object
        return_dict['license'][article['license']] = return_dict['license'].get(article['license'], 0) + 1

        ## Adds/UPDATES the most recent DOI submission from return_dict
        return_dict['content'][article['doi']] = {
            'date': article['date'],
            'license': article['license'],
            'jatsxml': article['jatsxml']
        }

# %%
def update_full_dict_by_date(articles, cur_date):
    '''
    This function adds to a dict object where the keys are the dates in string format and the values are a list of DOIs for that date
        @param articles: All articles in current date to extract information from
        @param cur_date: The current date to process in YYYY-mm-dd format
        @return: None
    '''
    cur_date = str(cur_date)
    articles = articles['collection']
    
    full_dict_by_date[cur_date] = [{'doi': item['doi'], 'license': item['license']} for item in articles]

# %%
def get_dated_subfolders(date):
    '''
    Function to create subfolders for each of the day, month, year in the current date, specifically to store metadata from "full_dict_by_date"
        @param date: The current date in YYYY-mm-dd format
        @return: The full output path for the folder representing the current date
    '''
    month = date.month
    year = date.year

    dict_main_folder = Path('./full-dict')

    dict_year_folder = dict_main_folder.joinpath(str(year))
    dict_year_folder.mkdir(exist_ok=True)

    dict_month_folder = dict_year_folder.joinpath(str(month))
    dict_month_folder.mkdir(exist_ok=True)

    return dict_month_folder

# %%
def split_dates(dates, num_splits):
    '''
    Function that takes in a list of dates (or anything, really) and splits those dates into num_splits number of splits
        @param dates: A list of dates (or anything really)
        @param num_splits: The number of sub-lists to split the original list into
    '''
    first_last_dates_fx = lambda lis: [[li[0], li[-1]] for li in lis] ## Essentially extracts the first and last elements of the split list of dates
    return list(first_last_dates_fx(np.array_split(dates, num_splits))) ## Returns the first and last dates of each split

# %%
def get_split_folder(split_num):
    '''
    Function that creates a folder for the specific split applicable to the current operation
        @param split_num: The split number to obtain the associated folder for
        @return: The path to the folder for the split number
    '''
    split_main_folder = Path('.')
    split_main_folder.mkdir(exist_ok=True)

    split_folder = split_main_folder.joinpath(str(split_num))
    split_folder.mkdir(exist_ok=True)

    return split_folder ## Not needed but just in case

# %%
def process_bioRxiv(start_date=lambda _: date(2013, 1, 1),
                    end_date=lambda _: date.today(),
                    load_dicts=False,
                    delay=5,
                    **kwargs):
    '''
    Function to process the data (loading in if necessary) for a period of time defined by:
        @param start: Beginning date in the format YYYY-mm-dd
        @param end: End date in the format YYY-mm-dd
        @param save_every: Saves (overrites) the last dict every n number of iterations through the data
        @param load_dicts: Loads in the dictionary (JSON) objects associated with "full_dict_by_date" and "return_dict"
    '''
    global full_dict_by_date
    full_dict_by_date = {}

    global return_dict
    return_dict = {
        'license': {},
        'content': {}
    }

    get_split_folder(SELECTED_NUMBER) ## Creates the folder for the current split number

    if load_dicts:
        with open(f'{SELECTED_NUMBER if SELECTED_NUMBER else "."}/full_dict_by_date.json', 'r') as f:
            full_dict_by_date = json.load(f)
        with open(f'{SELECTED_NUMBER if SELECTED_NUMBER else "."}/return_dict.json', 'r') as f:
            return_dict = json.load(f)

        start_date = date(full_dict_by_date.keys().sort()[-1]) + timedelta(days=1) ## Gets the last available date and adds 1 IF not the first date, otherwise starts at Jan 1, 2013

    dates = [start_date + timedelta(days=x) for x in range((end_date  - start_date).days + 1)] ## Gets a list of available dates

    for cur_date in dates:

        flag = True ## Flag of whether or not to continue the loop to get more pages
        num_skip = 0 ## Flag to skip as per API instructions
        while flag:
            cur_date_dir = get_dated_subfolders(cur_date)

            url = f'https://api.biorxiv.org/details/biorxiv/{str(cur_date)}/{str(cur_date)}/{num_skip}'

            response = requests.get(url) ## Processes request and waits for response / articles in JSON format
            response.raise_for_status()
            articles = response.json()

            if articles['messages'][0]['status'] != 'ok': ## Continues onto the next date if posts for the current date are unavailable
                flag = False
                continue

            update_full_dict_by_date(articles=articles, cur_date=cur_date)
            update_return_dict(articles=articles, cur_date=cur_date)

            print('Saving "full_dict_by_date.json"...')
            with open(f'./output_dicts/{SELECTED_NUMBER}/full_dict_by_date.json', 'w') as f:
                json.dump(full_dict_by_date, f, indent=2)
            
            print('Saving "return_dict.json"...')
            with open(f'./output_dicts{SELECTED_NUMBER}/return_dict.json', 'w') as f:
                json.dump(return_dict, f, indent=2)

            print('Saving "full_dict_by_date.json"...') ## Saves the updated JSONs
            with open(f'{str(cur_date_dir)}/{cur_date}.json', 'w') as f: ## Saves the whole output as today's date
                json.dump(articles['collection'], f, indent=2)

            print('='*50)
            print('Processed date:', cur_date, 'with', len(articles['collection']), 'articles')
            print(f'Sleeping for {delay} seconds... Zzz...')
            print('='*50)
            time.sleep(delay) ## Uses the default 5 seconds if need be

            num_skip += 100

# %% [markdown]
# # Directions for Asynchronous Users
#
# ---
#
# From the number you chose in the Discord server, please enter the number in the following cell under `SELECTED NUMBER`.
#
# DO NOT change the `DO_NOT_CHANGE_FLAG` flag. This represents the number of total splits to use.
#
# Afterwards, simply sync the current folder containing all the metadata with GitHub.

# %%
global DO_NOT_CHANGE_FLAG
DO_NOT_CHANGE_FLAG = 100 ## Do not change this number, it is the number of splits to create and is set standard to 100

# %%
LEFT_OFF = 53 ## The split number to start from, if 0, then starts from the beginning

# %%
for num in range(LEFT_OFF, DO_NOT_CHANGE_FLAG):
    global SELECTED_NUMBER
    SELECTED_NUMBER = num ## Enter selected number here, which represents the selected number

    dates = [date(2013, 1, 1) + timedelta(days=x) for x in range((date.today() - date(2013, 1, 1)).days + 1)] ## Gets a list of available dates
    split_dates_list = split_dates(dates, DO_NOT_CHANGE_FLAG) ## Splits the dates into the selected number of splits

    start_date = split_dates_list[SELECTED_NUMBER][0] ## Gets the start date from the selected number
    end_date = split_dates_list[SELECTED_NUMBER][1] ## Gets the end date from the selected number

    process_bioRxiv(start_date=start_date, end_date=end_date, save_every_n_days=100, load_dicts=False, delay=5)
# Out:
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-07 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-11 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-12 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-13 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-14 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-15 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-16 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-18 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-19 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-20 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-21 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-22 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-23 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-24 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-25 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-26 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-11-27 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-01 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-02 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-03 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-04 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-05 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-10 with 10 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-11 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-12 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-13 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-14 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-16 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-17 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-19 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-20 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-21 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-22 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-23 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-24 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-25 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-26 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-29 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-30 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2013-12-31 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-02 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-03 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-04 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-06 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-08 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-09 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-10 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-13 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-14 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-15 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-16 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-17 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-18 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-21 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-22 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-23 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-24 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-25 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-26 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-27 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-28 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-29 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-30 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-01-31 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-01 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-02 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-03 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-04 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-05 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-06 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-07 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-09 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-10 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-11 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-12 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-13 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-14 with 9 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-15 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-17 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-18 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-19 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-20 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-21 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-23 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-24 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-25 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-26 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-27 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-02-28 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-02 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-03 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-04 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-05 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-06 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-07 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-09 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-10 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-11 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-12 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-13 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-14 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-16 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-17 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-18 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-19 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-20 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-21 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-23 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-24 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-25 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-26 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-27 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-28 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-30 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-03-31 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-02 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-03 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-04 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-05 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-06 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-07 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-08 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-09 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-10 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-11 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-14 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-15 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-17 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-18 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-20 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-21 with 9 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-22 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-23 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-24 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-25 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-27 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-28 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-29 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-04-30 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-01 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-03 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-04 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-05 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-06 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-07 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-08 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-09 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-10 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-11 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-12 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-13 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-14 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-15 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-16 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-19 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-21 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-22 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-23 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-24 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-26 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-27 with 9 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-28 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-29 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-05-31 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-02 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-03 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-04 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-05 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-06 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-07 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-08 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-09 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-10 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-11 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-12 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-13 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-16 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-17 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-18 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-19 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-20 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-22 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-23 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-24 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-25 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-26 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-27 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-28 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-06-30 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-02 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-03 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-04 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-07 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-08 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-09 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-10 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-11 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-13 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-14 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-15 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-16 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-17 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-18 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-19 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-21 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-22 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-23 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-24 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-25 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-26 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-28 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-29 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-30 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-07-31 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-01 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-03 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-04 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-05 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-06 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-07 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-08 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-09 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-11 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-12 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-13 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-14 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-15 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-16 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-18 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-19 with 9 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-20 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-21 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-22 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-23 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-25 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-26 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-27 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-28 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-29 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-08-30 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-01 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-02 with 13 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-03 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-04 with 11 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-05 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-06 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-08 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-09 with 6 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-10 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-11 with 7 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-12 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-13 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-14 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-15 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-16 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-17 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-18 with 11 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-19 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-21 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-22 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-23 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-24 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-25 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-26 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-27 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-29 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-09-30 with 4 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-01 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-02 with 3 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-03 with 12 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-04 with 1 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-06 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-07 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2014-10-08 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# ...
# Processed date: 2018-08-31 with 48 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-01 with 14 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-02 with 8 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-03 with 99 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-04 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-04 with 14 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-05 with 86 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-06 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-06 with 28 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-07 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-07 with 5 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-08 with 35 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-09 with 49 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-10 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-10 with 36 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-11 with 79 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-12 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-12 with 35 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-13 with 88 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-14 with 98 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-15 with 27 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-16 with 39 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-17 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-18 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-18 with 26 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-19 with 75 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-20 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-20 with 28 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-21 with 97 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-22 with 22 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-23 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-23 with 2 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-24 with 79 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-25 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-26 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-26 with 18 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-27 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-27 with 65 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-28 with 64 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-29 with 93 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-09-30 with 35 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-01 with 89 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-02 with 92 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-03 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-03 with 61 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-04 with 88 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-05 with 100 articles
# Sleeping for 5 seconds... Zzz...
# Saving "full_dict_by_date.json"...
# Saving "return_dict.json"...
# Saving "full_dict_by_date.json"...
# Processed date: 2018-10-05 with 48 articles
# Sleeping for 5 seconds... Zzz...
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in _read_status(self)
#     288             # sending a valid response.
# --> 289             raise RemoteDisconnected("Remote end closed connection without"
#     290                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\Users\sunny\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\sunny\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# c:\Users\sunny\anaconda3\lib\http\client.py in _read_status(self)
#     288             # sending a valid response.
# --> 289             raise RemoteDisconnected("Remote end closed connection without"
#     290                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13328\1551009298.py in <module>
#       9     end_date = split_dates_list[SELECTED_NUMBER][1] ## Gets the end date from the selected number
#      10
# ---> 11     process_bioRxiv(start_date=start_date, end_date=end_date, save_every_n_days=100, load_dicts=False, delay=5)
#
# ~\AppData\Local\Temp\ipykernel_13328\2382036485.py in process_bioRxiv(start_date, end_date, load_dicts, delay, **kwargs)
#      41             url = f'https://api.biorxiv.org/details/biorxiv/{str(cur_date)}/{str(cur_date)}/{num_skip}'
#      42
# ---> 43             response = requests.get(url) ## Processes request and waits for response / articles in JSON format
#      44             response.raise_for_status()
#      45             articles = response.json()
#
# c:\Users\sunny\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\Users\sunny\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\Users\sunny\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\Users\sunny\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# c:\Users\sunny\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     545
#     546         except (ProtocolError, OSError) as err:
# --> 547             raise ConnectionError(err, request=request)
#     548
#     549         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# # Combine
#
# ---
#
# The below section deals with combining all of the obtained data into one single JSON object

# %%
def combine_output_dicts(base_dict, path='./output_dicts', num=0):
    '''
    Function to combine all of the output dicts into one JSON file
        @param path: The path to the folder containing all of the output dicts
        @return: None
    '''
    try:
        with open(f'{path}/{num}/return_dict.json', 'r') as f:
            cur_dict = json.load(f)
    except FileNotFoundError:
        print(f'No files in folder {num}...')

    for key, value in cur_dict.items():
        if key == 'license':
            for k, v in value.items():
                base_dict[key][k] += v
        elif key == 'content':
            base_dict[key] += value

# %%
def get_base_dict(path='./output_dicts'):
    '''
    Function to get the base dict for cobining all of the output dicts
        @param: None
        @return: Base dict
    '''
    for num in range(DO_NOT_CHANGE_FLAG):
        for dirpath, dirnames, filenames in os.walk(f'{num}'):
            if filenames:
                return num
    
    return None

# %%
base_dict = get_base_dict()
for num in range(DO_NOT_CHANGE_FLAG):
    combine_output_dicts(base_dict, f'./output_dicts/{num}')
